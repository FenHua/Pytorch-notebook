# %%
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets,transforms
torch.__version__
# Out:
# '1.0.1.post2'

# %%
BATCH_SIZE=512 #大概需要2G的显存
EPOCHS=30 # 总共训练批次
DEVICE=torch.device("cuda" if torch.cuda.is_available() else "cpu") # 让torch判断是否使用GPU
train_loader=torch.utils.data.DataLoader(datasets.MNIST('MNIST',train=True,download=True,
                                                        transform=transforms.Compose([
                                                            transforms.ToTensor(),
                                                            transforms.Normalize((0.1307,),(0.3081,))
                                                        ])),
                                        batch_size=BATCH_SIZE,shuffle=True)
test_loader=torch.utils.data.DataLoader(datasets.MNIST('MNIST',train=False,transform=transforms.Compose([
                                                          transforms.ToTensor(),
                                                          transforms.Normalize((0.1307,),(0.3081,))
                                                      ])),
                                       batch_size=BATCH_SIZE,shuffle=True)

# %%
class ConvNet(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv1=nn.Conv2d(1,10,5)
        self.conv2=nn.Conv2d(10,20,3)
        self.fc1=nn.Linear(20*10*10,500)
        self.fc2=nn.Linear(500,10)
    def forward(self,x):
        in_size=x.size(0) # 多少个数据
        out=self.conv1(x) # 24
        out=F.relu(out)
        out=F.max_pool2d(out,2,2) #12
        out=self.conv2(out) #10
        out=F.relu(out)
        out=out.view(in_size,-1)
        out=self.fc1(out)
        out=F.relu(out)
        out=self.fc2(out)
        out=F.log_softmax(out,dim=1)
        return out

# %%
model=ConvNet().to(DEVICE)
optimizer=optim.Adam(model.parameters())

# %%
def train(model,device,train_loader,optimizer,epoch):
    model.train()
    for batch_idx,(data,target) in enumerate(train_loader):
        data,target=data.to(device),target.to(device)
        optimizer.zero_grad()
        output=model(data)
        loss=F.nll_loss(output,target)  # 损失函数NLLLoss的输入是一个对数概率向量和一个目标标签. 它不会为我们计算对数概率，适合最后一层是log_softmax的网络.
        loss.backward()
        optimizer.step()
        if(batch_idx+1)%30==0:
            print("Train Epoch:{} [{}/{} ({:.0f}%)]\tLoss: {:.6f}".format(
            epoch,batch_idx*len(data),len(train_loader.dataset),
            100.*batch_idx/len(train_loader),loss.item()))

# %%
def test(model,device,test_loader):
    model.eval()
    test_loss=0
    correct=0
    with torch.no_grad():
        for data,target in test_loader:
            data,target=data.to(device),target.to(device)
            output=model(data)
            test_loss += F.nll_loss(output,target,reduction="sum").item() # 将一批损失相加
            pred=output.max(1,keepdim=True)[1] # 找到概率最大的下标
            correct +=pred.eq(target.view_as(pred)).sum().item()
    test_loss /= len(test_loader.dataset)
    print('\nTest set: Average loss:{:.4f},Accuracy: {}/{} ({:.0f}%)\n'.format(
    test_loss,correct,len(test_loader.dataset),
    100.*correct/len(test_loader.dataset)))

# %%
for epoch in range(1,EPOCHS+1):
    train(model,DEVICE,train_loader,optimizer,epoch)
    test(model,DEVICE,test_loader)
# Out:
# Train Epoch:1 [14848/60000 (25%)]	Loss: 0.000462
# Train Epoch:1 [30208/60000 (50%)]	Loss: 0.007453
# Train Epoch:1 [45568/60000 (75%)]	Loss: 0.003741
#
# Test set: Average loss:0.0391,Accuracy: 9905/10000 (99%)
#
# Train Epoch:2 [14848/60000 (25%)]	Loss: 0.007894
# Train Epoch:2 [30208/60000 (50%)]	Loss: 0.003272
# Train Epoch:2 [45568/60000 (75%)]	Loss: 0.004584
#
# Test set: Average loss:0.0395,Accuracy: 9913/10000 (99%)
#
# Train Epoch:3 [14848/60000 (25%)]	Loss: 0.004415
# Train Epoch:3 [30208/60000 (50%)]	Loss: 0.007624
# Train Epoch:3 [45568/60000 (75%)]	Loss: 0.002064
#
# Test set: Average loss:0.0408,Accuracy: 9903/10000 (99%)
#
# Train Epoch:4 [14848/60000 (25%)]	Loss: 0.000466
# Train Epoch:4 [30208/60000 (50%)]	Loss: 0.003700
# Train Epoch:4 [45568/60000 (75%)]	Loss: 0.017939
#
# Test set: Average loss:0.0427,Accuracy: 9908/10000 (99%)
#
# Train Epoch:5 [14848/60000 (25%)]	Loss: 0.001245
# Train Epoch:5 [30208/60000 (50%)]	Loss: 0.000413
# Train Epoch:5 [45568/60000 (75%)]	Loss: 0.000104
#
# Test set: Average loss:0.0336,Accuracy: 9924/10000 (99%)
#
# Train Epoch:6 [14848/60000 (25%)]	Loss: 0.000458
# Train Epoch:6 [30208/60000 (50%)]	Loss: 0.000236
# Train Epoch:6 [45568/60000 (75%)]	Loss: 0.000061
#
# Test set: Average loss:0.0307,Accuracy: 9926/10000 (99%)
#
# Train Epoch:7 [14848/60000 (25%)]	Loss: 0.000006
# Train Epoch:7 [30208/60000 (50%)]	Loss: 0.000609
# Train Epoch:7 [45568/60000 (75%)]	Loss: 0.000064
#
# Test set: Average loss:0.0311,Accuracy: 9929/10000 (99%)
#
# Train Epoch:8 [14848/60000 (25%)]	Loss: 0.000032
# Train Epoch:8 [30208/60000 (50%)]	Loss: 0.000012
# Train Epoch:8 [45568/60000 (75%)]	Loss: 0.000004
#
# Test set: Average loss:0.0314,Accuracy: 9929/10000 (99%)
#
# Train Epoch:9 [14848/60000 (25%)]	Loss: 0.000018
# Train Epoch:9 [30208/60000 (50%)]	Loss: 0.000007
# Train Epoch:9 [45568/60000 (75%)]	Loss: 0.000014
#
# Test set: Average loss:0.0317,Accuracy: 9929/10000 (99%)
#
# Train Epoch:10 [14848/60000 (25%)]	Loss: 0.000018
# Train Epoch:10 [30208/60000 (50%)]	Loss: 0.000011
# Train Epoch:10 [45568/60000 (75%)]	Loss: 0.000003
#
# Test set: Average loss:0.0321,Accuracy: 9930/10000 (99%)
#
# Train Epoch:11 [14848/60000 (25%)]	Loss: 0.000012
# Train Epoch:11 [30208/60000 (50%)]	Loss: 0.000013
# Train Epoch:11 [45568/60000 (75%)]	Loss: 0.000006
#
# Test set: Average loss:0.0325,Accuracy: 9930/10000 (99%)
#
# Train Epoch:12 [14848/60000 (25%)]	Loss: 0.000010
# Train Epoch:12 [30208/60000 (50%)]	Loss: 0.000028
# Train Epoch:12 [45568/60000 (75%)]	Loss: 0.000014
#
# Test set: Average loss:0.0327,Accuracy: 9929/10000 (99%)
#
# Train Epoch:13 [14848/60000 (25%)]	Loss: 0.000006
# Train Epoch:13 [30208/60000 (50%)]	Loss: 0.000014
# Train Epoch:13 [45568/60000 (75%)]	Loss: 0.000002
#
# Test set: Average loss:0.0331,Accuracy: 9931/10000 (99%)
#
# Train Epoch:14 [14848/60000 (25%)]	Loss: 0.000005
# Train Epoch:14 [30208/60000 (50%)]	Loss: 0.000015
# Train Epoch:14 [45568/60000 (75%)]	Loss: 0.000003
#
# Test set: Average loss:0.0333,Accuracy: 9930/10000 (99%)
#
# Train Epoch:15 [14848/60000 (25%)]	Loss: 0.000006
# Train Epoch:15 [30208/60000 (50%)]	Loss: 0.000009
# Train Epoch:15 [45568/60000 (75%)]	Loss: 0.000005
#
# Test set: Average loss:0.0337,Accuracy: 9929/10000 (99%)
#
# Train Epoch:16 [14848/60000 (25%)]	Loss: 0.000009
# Train Epoch:16 [30208/60000 (50%)]	Loss: 0.000004
# Train Epoch:16 [45568/60000 (75%)]	Loss: 0.000007
#
# Test set: Average loss:0.0339,Accuracy: 9929/10000 (99%)
#
# Train Epoch:17 [14848/60000 (25%)]	Loss: 0.000005
# Train Epoch:17 [30208/60000 (50%)]	Loss: 0.000010
# Train Epoch:17 [45568/60000 (75%)]	Loss: 0.000003
#
# Test set: Average loss:0.0342,Accuracy: 9929/10000 (99%)
#
# Train Epoch:18 [14848/60000 (25%)]	Loss: 0.000004
# Train Epoch:18 [30208/60000 (50%)]	Loss: 0.000004
# Train Epoch:18 [45568/60000 (75%)]	Loss: 0.000001
#
# Test set: Average loss:0.0345,Accuracy: 9929/10000 (99%)
#
# Train Epoch:19 [14848/60000 (25%)]	Loss: 0.000003
# Train Epoch:19 [30208/60000 (50%)]	Loss: 0.000005
# Train Epoch:19 [45568/60000 (75%)]	Loss: 0.000003
#
# Test set: Average loss:0.0348,Accuracy: 9930/10000 (99%)
#
# Train Epoch:20 [14848/60000 (25%)]	Loss: 0.000011
# Train Epoch:20 [30208/60000 (50%)]	Loss: 0.000003
# Train Epoch:20 [45568/60000 (75%)]	Loss: 0.000006
#
# Test set: Average loss:0.0350,Accuracy: 9930/10000 (99%)
#
# Train Epoch:21 [14848/60000 (25%)]	Loss: 0.000004
# Train Epoch:21 [30208/60000 (50%)]	Loss: 0.000002
# Train Epoch:21 [45568/60000 (75%)]	Loss: 0.000001
#
# Test set: Average loss:0.0353,Accuracy: 9928/10000 (99%)
#
# Train Epoch:22 [14848/60000 (25%)]	Loss: 0.000001
# Train Epoch:22 [30208/60000 (50%)]	Loss: 0.000002
# Train Epoch:22 [45568/60000 (75%)]	Loss: 0.000002
#
# Test set: Average loss:0.0354,Accuracy: 9930/10000 (99%)
#
# Train Epoch:23 [14848/60000 (25%)]	Loss: 0.000002
# Train Epoch:23 [30208/60000 (50%)]	Loss: 0.000004
# Train Epoch:23 [45568/60000 (75%)]	Loss: 0.000005
#
# Test set: Average loss:0.0357,Accuracy: 9929/10000 (99%)
#
# Train Epoch:24 [14848/60000 (25%)]	Loss: 0.000001
# Train Epoch:24 [30208/60000 (50%)]	Loss: 0.000007
# Train Epoch:24 [45568/60000 (75%)]	Loss: 0.000001
#
# Test set: Average loss:0.0359,Accuracy: 9928/10000 (99%)
#
# Train Epoch:25 [14848/60000 (25%)]	Loss: 0.000003
# Train Epoch:25 [30208/60000 (50%)]	Loss: 0.000003
# Train Epoch:25 [45568/60000 (75%)]	Loss: 0.000002
#
# Test set: Average loss:0.0362,Accuracy: 9930/10000 (99%)
#
# Train Epoch:26 [14848/60000 (25%)]	Loss: 0.000001
# Train Epoch:26 [30208/60000 (50%)]	Loss: 0.000003
# Train Epoch:26 [45568/60000 (75%)]	Loss: 0.000001
#
# Test set: Average loss:0.0364,Accuracy: 9931/10000 (99%)
#
# Train Epoch:27 [14848/60000 (25%)]	Loss: 0.000002
# Train Epoch:27 [30208/60000 (50%)]	Loss: 0.000002
# Train Epoch:27 [45568/60000 (75%)]	Loss: 0.000002
#
# Test set: Average loss:0.0365,Accuracy: 9929/10000 (99%)
#
# Train Epoch:28 [14848/60000 (25%)]	Loss: 0.000004
# Train Epoch:28 [30208/60000 (50%)]	Loss: 0.000000
# Train Epoch:28 [45568/60000 (75%)]	Loss: 0.000001
#
# Test set: Average loss:0.0368,Accuracy: 9928/10000 (99%)
#
# Train Epoch:29 [14848/60000 (25%)]	Loss: 0.000002
# Train Epoch:29 [30208/60000 (50%)]	Loss: 0.000003
# Train Epoch:29 [45568/60000 (75%)]	Loss: 0.000003
#
# Test set: Average loss:0.0370,Accuracy: 9928/10000 (99%)
#
# Train Epoch:30 [14848/60000 (25%)]	Loss: 0.000001
# Train Epoch:30 [30208/60000 (50%)]	Loss: 0.000001
# Train Epoch:30 [45568/60000 (75%)]	Loss: 0.000001
#
# Test set: Average loss:0.0372,Accuracy: 9930/10000 (99%)

# %%
torch.save(model.state_dict(),'model/model.pkl')

# %%
model.load_state_dict(torch.load('model/model.pkl'))

# %%
test(model,DEVICE,test_loader)
# Out:
# Test set: Average loss:0.0388,Accuracy: 9906/10000 (99%)

# %%
# 保存模型
torch.save({
    'epoch':epoch+1,
    'state_dict':model.state_dict(),
    'best_result':'99%'
},'model/model.pkl') # pickle 腌菜，腌制食品

# %%
# 加载模型
checkpoint=torch.load('model/model.pkl')
start_epoch=checkpoint['epoch']
best_result=checkpoint['best_result']
model.load_state_dict(checkpoint['state_dict'])

# %%
test(model,DEVICE,test_loader)
# Out:
# Test set: Average loss:0.0372,Accuracy: 9930/10000 (99%)

# %%
best_result
# Out:
# '99%'

# %%
params=model.state_dict()
for k,v in params.items():
    print(k) # 打印网络中的变量名
    print(params['conv1.weight']) # 打印conv1的weights
    print(params['conv1.bias'])
# Out:
# conv1.weight
# tensor([[[[ 0.0473, -0.1242, -0.1858, -0.0667,  0.2683],
#           [ 0.0933,  0.1241,  0.1764,  0.1326,  0.0780],
#           [-0.1828,  0.0375,  0.1603, -0.0414, -0.3911],
#           [ 0.0498, -0.0743,  0.0710, -0.0566, -0.1369],
#           [-0.1982,  0.0006,  0.0075,  0.1487,  0.1845]]],
#
#
#         [[[-0.2472, -0.3023, -0.1454,  0.2907,  0.0410],
#           [-0.3977, -0.1565,  0.2553,  0.2942, -0.0680],
#           [-0.3819, -0.1973,  0.3458,  0.0591, -0.0357],
#           [-0.2645, -0.2302,  0.1210, -0.0348,  0.2715],
#           [-0.0647, -0.0889, -0.1129, -0.0182,  0.1430]]],
#
#
#         [[[ 0.1846,  0.2150,  0.0590, -0.0621, -0.1213],
#           [-0.0629,  0.0778,  0.2212,  0.1107,  0.2403],
#           [ 0.0016, -0.0563,  0.3046,  0.0389,  0.1994],
#           [-0.1984, -0.0028, -0.1706,  0.0874,  0.0724],
#           [-0.3062, -0.3310, -0.3172, -0.0660, -0.3313]]],
#
#
#         [[[-0.1240, -0.1753, -0.3122, -0.2659, -0.1283],
#           [-0.2056, -0.3021, -0.1776, -0.1498, -0.1474],
#           [-0.2298, -0.0145,  0.0655,  0.1037,  0.1752],
#           [ 0.0074,  0.1525,  0.0289, -0.0053,  0.0089],
#           [-0.0952,  0.1743,  0.1404,  0.1580,  0.2284]]],
#
#
#         [[[ 0.1237,  0.1227, -0.1458, -0.2447,  0.1346],
#           [ 0.0950,  0.2306,  0.0310, -0.2957, -0.1644],
#           [-0.1608,  0.2470,  0.1937, -0.0262, -0.2047],
#           [ 0.0591,  0.1335,  0.0559, -0.0418,  0.0703],
#           [-0.1287,  0.1719,  0.2363, -0.1077,  0.0390]]],
#
#
#         [[[-0.0810,  0.1186, -0.1294, -0.2034, -0.0499],
#           [ 0.2526,  0.2549, -0.0710, -0.3497, -0.0112],
#           [ 0.3027,  0.0110, -0.2560, -0.3005, -0.1067],
#           [ 0.2773,  0.2219,  0.0554, -0.0651, -0.0885],
#           [ 0.1367, -0.1514, -0.3074, -0.1992,  0.2225]]],
#
#
#         [[[ 0.0220, -0.1393,  0.2391,  0.0354, -0.1309],
#           [ 0.1662,  0.2442, -0.0303,  0.1536, -0.1857],
#           [-0.0571,  0.1664, -0.1277, -0.0071, -0.3380],
#           [ 0.1753,  0.1025, -0.1652,  0.1522, -0.0153],
#           [-0.2676,  0.0350,  0.0850, -0.0108,  0.2412]]],
#
#
#         [[[-0.0936, -0.0724, -0.1145,  0.1809,  0.1123],
#           [ 0.0697,  0.2309,  0.0336,  0.2533,  0.1725],
#           [ 0.0659,  0.2416,  0.0571,  0.1563,  0.0774],
#           [-0.1848, -0.1439, -0.1821, -0.0702, -0.1202],
#           [ 0.1542,  0.0665,  0.0406, -0.1901, -0.3174]]],
#
#
#         [[[ 0.0837,  0.0153,  0.2334, -0.0559, -0.3326],
#           [-0.1655, -0.0735,  0.3182,  0.1149, -0.2299],
#           [-0.1970, -0.0713,  0.3137, -0.0336,  0.0705],
#           [-0.2605,  0.1102,  0.0249,  0.0049, -0.0116],
#           [ 0.0366, -0.1495,  0.1592, -0.0636,  0.1053]]],
#
#
#         [[[-0.1465, -0.0688, -0.1923,  0.0018,  0.2641],
#           [-0.1228, -0.1574, -0.3342, -0.2719,  0.0285],
#           [ 0.3145,  0.1077, -0.1280, -0.3167,  0.0511],
#           [ 0.2035,  0.0950,  0.2908, -0.1905, -0.0051],
#           [ 0.0710,  0.0933,  0.1470,  0.1892, -0.1844]]]], device='cuda:0')
# tensor([ 0.0676,  0.1510, -0.0481,  0.0978, -0.1315, -0.0666,  0.1526,  0.1776,
#         -0.2446,  0.2205], device='cuda:0')
# conv1.bias
# tensor([[[[ 0.0473, -0.1242, -0.1858, -0.0667,  0.2683],
#           [ 0.0933,  0.1241,  0.1764,  0.1326,  0.0780],
#           [-0.1828,  0.0375,  0.1603, -0.0414, -0.3911],
#           [ 0.0498, -0.0743,  0.0710, -0.0566, -0.1369],
#           [-0.1982,  0.0006,  0.0075,  0.1487,  0.1845]]],
#
#
#         [[[-0.2472, -0.3023, -0.1454,  0.2907,  0.0410],
#           [-0.3977, -0.1565,  0.2553,  0.2942, -0.0680],
#           [-0.3819, -0.1973,  0.3458,  0.0591, -0.0357],
#           [-0.2645, -0.2302,  0.1210, -0.0348,  0.2715],
#           [-0.0647, -0.0889, -0.1129, -0.0182,  0.1430]]],
#
#
#         [[[ 0.1846,  0.2150,  0.0590, -0.0621, -0.1213],
#           [-0.0629,  0.0778,  0.2212,  0.1107,  0.2403],
#           [ 0.0016, -0.0563,  0.3046,  0.0389,  0.1994],
#           [-0.1984, -0.0028, -0.1706,  0.0874,  0.0724],
#           [-0.3062, -0.3310, -0.3172, -0.0660, -0.3313]]],
#
#
#         [[[-0.1240, -0.1753, -0.3122, -0.2659, -0.1283],
#           [-0.2056, -0.3021, -0.1776, -0.1498, -0.1474],
#           [-0.2298, -0.0145,  0.0655,  0.1037,  0.1752],
#           [ 0.0074,  0.1525,  0.0289, -0.0053,  0.0089],
#           [-0.0952,  0.1743,  0.1404,  0.1580,  0.2284]]],
#
#
#         [[[ 0.1237,  0.1227, -0.1458, -0.2447,  0.1346],
#           [ 0.0950,  0.2306,  0.0310, -0.2957, -0.1644],
#           [-0.1608,  0.2470,  0.1937, -0.0262, -0.2047],
#           [ 0.0591,  0.1335,  0.0559, -0.0418,  0.0703],
#           [-0.1287,  0.1719,  0.2363, -0.1077,  0.0390]]],
#
#
#         [[[-0.0810,  0.1186, -0.1294, -0.2034, -0.0499],
#           [ 0.2526,  0.2549, -0.0710, -0.3497, -0.0112],
#           [ 0.3027,  0.0110, -0.2560, -0.3005, -0.1067],
#           [ 0.2773,  0.2219,  0.0554, -0.0651, -0.0885],
#           [ 0.1367, -0.1514, -0.3074, -0.1992,  0.2225]]],
#
#
#         [[[ 0.0220, -0.1393,  0.2391,  0.0354, -0.1309],
#           [ 0.1662,  0.2442, -0.0303,  0.1536, -0.1857],
#           [-0.0571,  0.1664, -0.1277, -0.0071, -0.3380],
#           [ 0.1753,  0.1025, -0.1652,  0.1522, -0.0153],
#           [-0.2676,  0.0350,  0.0850, -0.0108,  0.2412]]],
#
#
#         [[[-0.0936, -0.0724, -0.1145,  0.1809,  0.1123],
#           [ 0.0697,  0.2309,  0.0336,  0.2533,  0.1725],
#           [ 0.0659,  0.2416,  0.0571,  0.1563,  0.0774],
#           [-0.1848, -0.1439, -0.1821, -0.0702, -0.1202],
#           [ 0.1542,  0.0665,  0.0406, -0.1901, -0.3174]]],
#
#
#         [[[ 0.0837,  0.0153,  0.2334, -0.0559, -0.3326],
#           [-0.1655, -0.0735,  0.3182,  0.1149, -0.2299],
#           [-0.1970, -0.0713,  0.3137, -0.0336,  0.0705],
#           [-0.2605,  0.1102,  0.0249,  0.0049, -0.0116],
#           [ 0.0366, -0.1495,  0.1592, -0.0636,  0.1053]]],
#
#
#         [[[-0.1465, -0.0688, -0.1923,  0.0018,  0.2641],
#           [-0.1228, -0.1574, -0.3342, -0.2719,  0.0285],
#           [ 0.3145,  0.1077, -0.1280, -0.3167,  0.0511],
#           [ 0.2035,  0.0950,  0.2908, -0.1905, -0.0051],
#           [ 0.0710,  0.0933,  0.1470,  0.1892, -0.1844]]]], device='cuda:0')
# tensor([ 0.0676,  0.1510, -0.0481,  0.0978, -0.1315, -0.0666,  0.1526,  0.1776,
#         -0.2446,  0.2205], device='cuda:0')
# conv2.weight
# tensor([[[[ 0.0473, -0.1242, -0.1858, -0.0667,  0.2683],
#           [ 0.0933,  0.1241,  0.1764,  0.1326,  0.0780],
#           [-0.1828,  0.0375,  0.1603, -0.0414, -0.3911],
#           [ 0.0498, -0.0743,  0.0710, -0.0566, -0.1369],
#           [-0.1982,  0.0006,  0.0075,  0.1487,  0.1845]]],
#
#
#         [[[-0.2472, -0.3023, -0.1454,  0.2907,  0.0410],
#           [-0.3977, -0.1565,  0.2553,  0.2942, -0.0680],
#           [-0.3819, -0.1973,  0.3458,  0.0591, -0.0357],
#           [-0.2645, -0.2302,  0.1210, -0.0348,  0.2715],
#           [-0.0647, -0.0889, -0.1129, -0.0182,  0.1430]]],
#
#
#         [[[ 0.1846,  0.2150,  0.0590, -0.0621, -0.1213],
#           [-0.0629,  0.0778,  0.2212,  0.1107,  0.2403],
#           [ 0.0016, -0.0563,  0.3046,  0.0389,  0.1994],
#           [-0.1984, -0.0028, -0.1706,  0.0874,  0.0724],
#           [-0.3062, -0.3310, -0.3172, -0.0660, -0.3313]]],
#
#
#         [[[-0.1240, -0.1753, -0.3122, -0.2659, -0.1283],
#           [-0.2056, -0.3021, -0.1776, -0.1498, -0.1474],
#           [-0.2298, -0.0145,  0.0655,  0.1037,  0.1752],
#           [ 0.0074,  0.1525,  0.0289, -0.0053,  0.0089],
#           [-0.0952,  0.1743,  0.1404,  0.1580,  0.2284]]],
#
#
#         [[[ 0.1237,  0.1227, -0.1458, -0.2447,  0.1346],
#           [ 0.0950,  0.2306,  0.0310, -0.2957, -0.1644],
#           [-0.1608,  0.2470,  0.1937, -0.0262, -0.2047],
#           [ 0.0591,  0.1335,  0.0559, -0.0418,  0.0703],
#           [-0.1287,  0.1719,  0.2363, -0.1077,  0.0390]]],
#
#
#         [[[-0.0810,  0.1186, -0.1294, -0.2034, -0.0499],
#           [ 0.2526,  0.2549, -0.0710, -0.3497, -0.0112],
#           [ 0.3027,  0.0110, -0.2560, -0.3005, -0.1067],
#           [ 0.2773,  0.2219,  0.0554, -0.0651, -0.0885],
#           [ 0.1367, -0.1514, -0.3074, -0.1992,  0.2225]]],
#
#
#         [[[ 0.0220, -0.1393,  0.2391,  0.0354, -0.1309],
#           [ 0.1662,  0.2442, -0.0303,  0.1536, -0.1857],
#           [-0.0571,  0.1664, -0.1277, -0.0071, -0.3380],
#           [ 0.1753,  0.1025, -0.1652,  0.1522, -0.0153],
#           [-0.2676,  0.0350,  0.0850, -0.0108,  0.2412]]],
#
#
#         [[[-0.0936, -0.0724, -0.1145,  0.1809,  0.1123],
#           [ 0.0697,  0.2309,  0.0336,  0.2533,  0.1725],
#           [ 0.0659,  0.2416,  0.0571,  0.1563,  0.0774],
#           [-0.1848, -0.1439, -0.1821, -0.0702, -0.1202],
#           [ 0.1542,  0.0665,  0.0406, -0.1901, -0.3174]]],
#
#
#         [[[ 0.0837,  0.0153,  0.2334, -0.0559, -0.3326],
#           [-0.1655, -0.0735,  0.3182,  0.1149, -0.2299],
#           [-0.1970, -0.0713,  0.3137, -0.0336,  0.0705],
#           [-0.2605,  0.1102,  0.0249,  0.0049, -0.0116],
#           [ 0.0366, -0.1495,  0.1592, -0.0636,  0.1053]]],
#
#
#         [[[-0.1465, -0.0688, -0.1923,  0.0018,  0.2641],
#           [-0.1228, -0.1574, -0.3342, -0.2719,  0.0285],
#           [ 0.3145,  0.1077, -0.1280, -0.3167,  0.0511],
#           [ 0.2035,  0.0950,  0.2908, -0.1905, -0.0051],
#           [ 0.0710,  0.0933,  0.1470,  0.1892, -0.1844]]]], device='cuda:0')
# tensor([ 0.0676,  0.1510, -0.0481,  0.0978, -0.1315, -0.0666,  0.1526,  0.1776,
#         -0.2446,  0.2205], device='cuda:0')
# conv2.bias
# tensor([[[[ 0.0473, -0.1242, -0.1858, -0.0667,  0.2683],
#           [ 0.0933,  0.1241,  0.1764,  0.1326,  0.0780],
#           [-0.1828,  0.0375,  0.1603, -0.0414, -0.3911],
#           [ 0.0498, -0.0743,  0.0710, -0.0566, -0.1369],
#           [-0.1982,  0.0006,  0.0075,  0.1487,  0.1845]]],
#
#
#         [[[-0.2472, -0.3023, -0.1454,  0.2907,  0.0410],
#           [-0.3977, -0.1565,  0.2553,  0.2942, -0.0680],
#           [-0.3819, -0.1973,  0.3458,  0.0591, -0.0357],
#           [-0.2645, -0.2302,  0.1210, -0.0348,  0.2715],
#           [-0.0647, -0.0889, -0.1129, -0.0182,  0.1430]]],
#
#
#         [[[ 0.1846,  0.2150,  0.0590, -0.0621, -0.1213],
#           [-0.0629,  0.0778,  0.2212,  0.1107,  0.2403],
#           [ 0.0016, -0.0563,  0.3046,  0.0389,  0.1994],
#           [-0.1984, -0.0028, -0.1706,  0.0874,  0.0724],
#           [-0.3062, -0.3310, -0.3172, -0.0660, -0.3313]]],
#
#
#         [[[-0.1240, -0.1753, -0.3122, -0.2659, -0.1283],
#           [-0.2056, -0.3021, -0.1776, -0.1498, -0.1474],
#           [-0.2298, -0.0145,  0.0655,  0.1037,  0.1752],
#           [ 0.0074,  0.1525,  0.0289, -0.0053,  0.0089],
#           [-0.0952,  0.1743,  0.1404,  0.1580,  0.2284]]],
#
#
#         [[[ 0.1237,  0.1227, -0.1458, -0.2447,  0.1346],
#           [ 0.0950,  0.2306,  0.0310, -0.2957, -0.1644],
#           [-0.1608,  0.2470,  0.1937, -0.0262, -0.2047],
#           [ 0.0591,  0.1335,  0.0559, -0.0418,  0.0703],
#           [-0.1287,  0.1719,  0.2363, -0.1077,  0.0390]]],
#
#
#         [[[-0.0810,  0.1186, -0.1294, -0.2034, -0.0499],
#           [ 0.2526,  0.2549, -0.0710, -0.3497, -0.0112],
#           [ 0.3027,  0.0110, -0.2560, -0.3005, -0.1067],
#           [ 0.2773,  0.2219,  0.0554, -0.0651, -0.0885],
#           [ 0.1367, -0.1514, -0.3074, -0.1992,  0.2225]]],
#
#
#         [[[ 0.0220, -0.1393,  0.2391,  0.0354, -0.1309],
#           [ 0.1662,  0.2442, -0.0303,  0.1536, -0.1857],
#           [-0.0571,  0.1664, -0.1277, -0.0071, -0.3380],
#           [ 0.1753,  0.1025, -0.1652,  0.1522, -0.0153],
#           [-0.2676,  0.0350,  0.0850, -0.0108,  0.2412]]],
#
#
#         [[[-0.0936, -0.0724, -0.1145,  0.1809,  0.1123],
#           [ 0.0697,  0.2309,  0.0336,  0.2533,  0.1725],
#           [ 0.0659,  0.2416,  0.0571,  0.1563,  0.0774],
#           [-0.1848, -0.1439, -0.1821, -0.0702, -0.1202],
#           [ 0.1542,  0.0665,  0.0406, -0.1901, -0.3174]]],
#
#
#         [[[ 0.0837,  0.0153,  0.2334, -0.0559, -0.3326],
#           [-0.1655, -0.0735,  0.3182,  0.1149, -0.2299],
#           [-0.1970, -0.0713,  0.3137, -0.0336,  0.0705],
#           [-0.2605,  0.1102,  0.0249,  0.0049, -0.0116],
#           [ 0.0366, -0.1495,  0.1592, -0.0636,  0.1053]]],
#
#
#         [[[-0.1465, -0.0688, -0.1923,  0.0018,  0.2641],
#           [-0.1228, -0.1574, -0.3342, -0.2719,  0.0285],
#           [ 0.3145,  0.1077, -0.1280, -0.3167,  0.0511],
#           [ 0.2035,  0.0950,  0.2908, -0.1905, -0.0051],
#           [ 0.0710,  0.0933,  0.1470,  0.1892, -0.1844]]]], device='cuda:0')
# tensor([ 0.0676,  0.1510, -0.0481,  0.0978, -0.1315, -0.0666,  0.1526,  0.1776,
#         -0.2446,  0.2205], device='cuda:0')
# fc1.weight
# tensor([[[[ 0.0473, -0.1242, -0.1858, -0.0667,  0.2683],
#           [ 0.0933,  0.1241,  0.1764,  0.1326,  0.0780],
#           [-0.1828,  0.0375,  0.1603, -0.0414, -0.3911],
#           [ 0.0498, -0.0743,  0.0710, -0.0566, -0.1369],
#           [-0.1982,  0.0006,  0.0075,  0.1487,  0.1845]]],
#
#
#         [[[-0.2472, -0.3023, -0.1454,  0.2907,  0.0410],
#           [-0.3977, -0.1565,  0.2553,  0.2942, -0.0680],
#           [-0.3819, -0.1973,  0.3458,  0.0591, -0.0357],
#           [-0.2645, -0.2302,  0.1210, -0.0348,  0.2715],
#           [-0.0647, -0.0889, -0.1129, -0.0182,  0.1430]]],
#
#
#         [[[ 0.1846,  0.2150,  0.0590, -0.0621, -0.1213],
#           [-0.0629,  0.0778,  0.2212,  0.1107,  0.2403],
#           [ 0.0016, -0.0563,  0.3046,  0.0389,  0.1994],
#           [-0.1984, -0.0028, -0.1706,  0.0874,  0.0724],
#           [-0.3062, -0.3310, -0.3172, -0.0660, -0.3313]]],
#
#
#         [[[-0.1240, -0.1753, -0.3122, -0.2659, -0.1283],
#           [-0.2056, -0.3021, -0.1776, -0.1498, -0.1474],
#           [-0.2298, -0.0145,  0.0655,  0.1037,  0.1752],
#           [ 0.0074,  0.1525,  0.0289, -0.0053,  0.0089],
#           [-0.0952,  0.1743,  0.1404,  0.1580,  0.2284]]],
#
#
#         [[[ 0.1237,  0.1227, -0.1458, -0.2447,  0.1346],
#           [ 0.0950,  0.2306,  0.0310, -0.2957, -0.1644],
#           [-0.1608,  0.2470,  0.1937, -0.0262, -0.2047],
#           [ 0.0591,  0.1335,  0.0559, -0.0418,  0.0703],
#           [-0.1287,  0.1719,  0.2363, -0.1077,  0.0390]]],
#
#
#         [[[-0.0810,  0.1186, -0.1294, -0.2034, -0.0499],
#           [ 0.2526,  0.2549, -0.0710, -0.3497, -0.0112],
#           [ 0.3027,  0.0110, -0.2560, -0.3005, -0.1067],
#           [ 0.2773,  0.2219,  0.0554, -0.0651, -0.0885],
#           [ 0.1367, -0.1514, -0.3074, -0.1992,  0.2225]]],
#
#
#         [[[ 0.0220, -0.1393,  0.2391,  0.0354, -0.1309],
#           [ 0.1662,  0.2442, -0.0303,  0.1536, -0.1857],
#           [-0.0571,  0.1664, -0.1277, -0.0071, -0.3380],
#           [ 0.1753,  0.1025, -0.1652,  0.1522, -0.0153],
#           [-0.2676,  0.0350,  0.0850, -0.0108,  0.2412]]],
#
#
#         [[[-0.0936, -0.0724, -0.1145,  0.1809,  0.1123],
#           [ 0.0697,  0.2309,  0.0336,  0.2533,  0.1725],
#           [ 0.0659,  0.2416,  0.0571,  0.1563,  0.0774],
#           [-0.1848, -0.1439, -0.1821, -0.0702, -0.1202],
#           [ 0.1542,  0.0665,  0.0406, -0.1901, -0.3174]]],
#
#
#         [[[ 0.0837,  0.0153,  0.2334, -0.0559, -0.3326],
#           [-0.1655, -0.0735,  0.3182,  0.1149, -0.2299],
#           [-0.1970, -0.0713,  0.3137, -0.0336,  0.0705],
#           [-0.2605,  0.1102,  0.0249,  0.0049, -0.0116],
#           [ 0.0366, -0.1495,  0.1592, -0.0636,  0.1053]]],
#
#
#         [[[-0.1465, -0.0688, -0.1923,  0.0018,  0.2641],
#           [-0.1228, -0.1574, -0.3342, -0.2719,  0.0285],
#           [ 0.3145,  0.1077, -0.1280, -0.3167,  0.0511],
#           [ 0.2035,  0.0950,  0.2908, -0.1905, -0.0051],
#           [ 0.0710,  0.0933,  0.1470,  0.1892, -0.1844]]]], device='cuda:0')
# tensor([ 0.0676,  0.1510, -0.0481,  0.0978, -0.1315, -0.0666,  0.1526,  0.1776,
#         -0.2446,  0.2205], device='cuda:0')
# fc1.bias
# tensor([[[[ 0.0473, -0.1242, -0.1858, -0.0667,  0.2683],
#           [ 0.0933,  0.1241,  0.1764,  0.1326,  0.0780],
#           [-0.1828,  0.0375,  0.1603, -0.0414, -0.3911],
#           [ 0.0498, -0.0743,  0.0710, -0.0566, -0.1369],
#           [-0.1982,  0.0006,  0.0075,  0.1487,  0.1845]]],
#
#
#         [[[-0.2472, -0.3023, -0.1454,  0.2907,  0.0410],
#           [-0.3977, -0.1565,  0.2553,  0.2942, -0.0680],
#           [-0.3819, -0.1973,  0.3458,  0.0591, -0.0357],
#           [-0.2645, -0.2302,  0.1210, -0.0348,  0.2715],
#           [-0.0647, -0.0889, -0.1129, -0.0182,  0.1430]]],
#
#
#         [[[ 0.1846,  0.2150,  0.0590, -0.0621, -0.1213],
#           [-0.0629,  0.0778,  0.2212,  0.1107,  0.2403],
#           [ 0.0016, -0.0563,  0.3046,  0.0389,  0.1994],
#           [-0.1984, -0.0028, -0.1706,  0.0874,  0.0724],
#           [-0.3062, -0.3310, -0.3172, -0.0660, -0.3313]]],
#
#
#         [[[-0.1240, -0.1753, -0.3122, -0.2659, -0.1283],
#           [-0.2056, -0.3021, -0.1776, -0.1498, -0.1474],
#           [-0.2298, -0.0145,  0.0655,  0.1037,  0.1752],
#           [ 0.0074,  0.1525,  0.0289, -0.0053,  0.0089],
#           [-0.0952,  0.1743,  0.1404,  0.1580,  0.2284]]],
#
#
#         [[[ 0.1237,  0.1227, -0.1458, -0.2447,  0.1346],
#           [ 0.0950,  0.2306,  0.0310, -0.2957, -0.1644],
#           [-0.1608,  0.2470,  0.1937, -0.0262, -0.2047],
#           [ 0.0591,  0.1335,  0.0559, -0.0418,  0.0703],
#           [-0.1287,  0.1719,  0.2363, -0.1077,  0.0390]]],
#
#
#         [[[-0.0810,  0.1186, -0.1294, -0.2034, -0.0499],
#           [ 0.2526,  0.2549, -0.0710, -0.3497, -0.0112],
#           [ 0.3027,  0.0110, -0.2560, -0.3005, -0.1067],
#           [ 0.2773,  0.2219,  0.0554, -0.0651, -0.0885],
#           [ 0.1367, -0.1514, -0.3074, -0.1992,  0.2225]]],
#
#
#         [[[ 0.0220, -0.1393,  0.2391,  0.0354, -0.1309],
#           [ 0.1662,  0.2442, -0.0303,  0.1536, -0.1857],
#           [-0.0571,  0.1664, -0.1277, -0.0071, -0.3380],
#           [ 0.1753,  0.1025, -0.1652,  0.1522, -0.0153],
#           [-0.2676,  0.0350,  0.0850, -0.0108,  0.2412]]],
#
#
#         [[[-0.0936, -0.0724, -0.1145,  0.1809,  0.1123],
#           [ 0.0697,  0.2309,  0.0336,  0.2533,  0.1725],
#           [ 0.0659,  0.2416,  0.0571,  0.1563,  0.0774],
#           [-0.1848, -0.1439, -0.1821, -0.0702, -0.1202],
#           [ 0.1542,  0.0665,  0.0406, -0.1901, -0.3174]]],
#
#
#         [[[ 0.0837,  0.0153,  0.2334, -0.0559, -0.3326],
#           [-0.1655, -0.0735,  0.3182,  0.1149, -0.2299],
#           [-0.1970, -0.0713,  0.3137, -0.0336,  0.0705],
#           [-0.2605,  0.1102,  0.0249,  0.0049, -0.0116],
#           [ 0.0366, -0.1495,  0.1592, -0.0636,  0.1053]]],
#
#
#         [[[-0.1465, -0.0688, -0.1923,  0.0018,  0.2641],
#           [-0.1228, -0.1574, -0.3342, -0.2719,  0.0285],
#           [ 0.3145,  0.1077, -0.1280, -0.3167,  0.0511],
#           [ 0.2035,  0.0950,  0.2908, -0.1905, -0.0051],
#           [ 0.0710,  0.0933,  0.1470,  0.1892, -0.1844]]]], device='cuda:0')
# tensor([ 0.0676,  0.1510, -0.0481,  0.0978, -0.1315, -0.0666,  0.1526,  0.1776,
#         -0.2446,  0.2205], device='cuda:0')
# fc2.weight
# tensor([[[[ 0.0473, -0.1242, -0.1858, -0.0667,  0.2683],
#           [ 0.0933,  0.1241,  0.1764,  0.1326,  0.0780],
#           [-0.1828,  0.0375,  0.1603, -0.0414, -0.3911],
#           [ 0.0498, -0.0743,  0.0710, -0.0566, -0.1369],
#           [-0.1982,  0.0006,  0.0075,  0.1487,  0.1845]]],
#
#
#         [[[-0.2472, -0.3023, -0.1454,  0.2907,  0.0410],
#           [-0.3977, -0.1565,  0.2553,  0.2942, -0.0680],
#           [-0.3819, -0.1973,  0.3458,  0.0591, -0.0357],
#           [-0.2645, -0.2302,  0.1210, -0.0348,  0.2715],
#           [-0.0647, -0.0889, -0.1129, -0.0182,  0.1430]]],
#
#
#         [[[ 0.1846,  0.2150,  0.0590, -0.0621, -0.1213],
#           [-0.0629,  0.0778,  0.2212,  0.1107,  0.2403],
#           [ 0.0016, -0.0563,  0.3046,  0.0389,  0.1994],
#           [-0.1984, -0.0028, -0.1706,  0.0874,  0.0724],
#           [-0.3062, -0.3310, -0.3172, -0.0660, -0.3313]]],
#
#
#         [[[-0.1240, -0.1753, -0.3122, -0.2659, -0.1283],
#           [-0.2056, -0.3021, -0.1776, -0.1498, -0.1474],
#           [-0.2298, -0.0145,  0.0655,  0.1037,  0.1752],
#           [ 0.0074,  0.1525,  0.0289, -0.0053,  0.0089],
#           [-0.0952,  0.1743,  0.1404,  0.1580,  0.2284]]],
#
#
#         [[[ 0.1237,  0.1227, -0.1458, -0.2447,  0.1346],
#           [ 0.0950,  0.2306,  0.0310, -0.2957, -0.1644],
#           [-0.1608,  0.2470,  0.1937, -0.0262, -0.2047],
#           [ 0.0591,  0.1335,  0.0559, -0.0418,  0.0703],
#           [-0.1287,  0.1719,  0.2363, -0.1077,  0.0390]]],
#
#
#         [[[-0.0810,  0.1186, -0.1294, -0.2034, -0.0499],
#           [ 0.2526,  0.2549, -0.0710, -0.3497, -0.0112],
#           [ 0.3027,  0.0110, -0.2560, -0.3005, -0.1067],
#           [ 0.2773,  0.2219,  0.0554, -0.0651, -0.0885],
#           [ 0.1367, -0.1514, -0.3074, -0.1992,  0.2225]]],
#
#
#         [[[ 0.0220, -0.1393,  0.2391,  0.0354, -0.1309],
#           [ 0.1662,  0.2442, -0.0303,  0.1536, -0.1857],
#           [-0.0571,  0.1664, -0.1277, -0.0071, -0.3380],
#           [ 0.1753,  0.1025, -0.1652,  0.1522, -0.0153],
#           [-0.2676,  0.0350,  0.0850, -0.0108,  0.2412]]],
#
#
#         [[[-0.0936, -0.0724, -0.1145,  0.1809,  0.1123],
#           [ 0.0697,  0.2309,  0.0336,  0.2533,  0.1725],
#           [ 0.0659,  0.2416,  0.0571,  0.1563,  0.0774],
#           [-0.1848, -0.1439, -0.1821, -0.0702, -0.1202],
#           [ 0.1542,  0.0665,  0.0406, -0.1901, -0.3174]]],
#
#
#         [[[ 0.0837,  0.0153,  0.2334, -0.0559, -0.3326],
#           [-0.1655, -0.0735,  0.3182,  0.1149, -0.2299],
#           [-0.1970, -0.0713,  0.3137, -0.0336,  0.0705],
#           [-0.2605,  0.1102,  0.0249,  0.0049, -0.0116],
#           [ 0.0366, -0.1495,  0.1592, -0.0636,  0.1053]]],
#
#
#         [[[-0.1465, -0.0688, -0.1923,  0.0018,  0.2641],
#           [-0.1228, -0.1574, -0.3342, -0.2719,  0.0285],
#           [ 0.3145,  0.1077, -0.1280, -0.3167,  0.0511],
#           [ 0.2035,  0.0950,  0.2908, -0.1905, -0.0051],
#           [ 0.0710,  0.0933,  0.1470,  0.1892, -0.1844]]]], device='cuda:0')
# tensor([ 0.0676,  0.1510, -0.0481,  0.0978, -0.1315, -0.0666,  0.1526,  0.1776,
#         -0.2446,  0.2205], device='cuda:0')
# fc2.bias
# tensor([[[[ 0.0473, -0.1242, -0.1858, -0.0667,  0.2683],
#           [ 0.0933,  0.1241,  0.1764,  0.1326,  0.0780],
#           [-0.1828,  0.0375,  0.1603, -0.0414, -0.3911],
#           [ 0.0498, -0.0743,  0.0710, -0.0566, -0.1369],
#           [-0.1982,  0.0006,  0.0075,  0.1487,  0.1845]]],
#
#
#         [[[-0.2472, -0.3023, -0.1454,  0.2907,  0.0410],
#           [-0.3977, -0.1565,  0.2553,  0.2942, -0.0680],
#           [-0.3819, -0.1973,  0.3458,  0.0591, -0.0357],
#           [-0.2645, -0.2302,  0.1210, -0.0348,  0.2715],
#           [-0.0647, -0.0889, -0.1129, -0.0182,  0.1430]]],
#
#
#         [[[ 0.1846,  0.2150,  0.0590, -0.0621, -0.1213],
#           [-0.0629,  0.0778,  0.2212,  0.1107,  0.2403],
#           [ 0.0016, -0.0563,  0.3046,  0.0389,  0.1994],
#           [-0.1984, -0.0028, -0.1706,  0.0874,  0.0724],
#           [-0.3062, -0.3310, -0.3172, -0.0660, -0.3313]]],
#
#
#         [[[-0.1240, -0.1753, -0.3122, -0.2659, -0.1283],
#           [-0.2056, -0.3021, -0.1776, -0.1498, -0.1474],
#           [-0.2298, -0.0145,  0.0655,  0.1037,  0.1752],
#           [ 0.0074,  0.1525,  0.0289, -0.0053,  0.0089],
#           [-0.0952,  0.1743,  0.1404,  0.1580,  0.2284]]],
#
#
#         [[[ 0.1237,  0.1227, -0.1458, -0.2447,  0.1346],
#           [ 0.0950,  0.2306,  0.0310, -0.2957, -0.1644],
#           [-0.1608,  0.2470,  0.1937, -0.0262, -0.2047],
#           [ 0.0591,  0.1335,  0.0559, -0.0418,  0.0703],
#           [-0.1287,  0.1719,  0.2363, -0.1077,  0.0390]]],
#
#
#         [[[-0.0810,  0.1186, -0.1294, -0.2034, -0.0499],
#           [ 0.2526,  0.2549, -0.0710, -0.3497, -0.0112],
#           [ 0.3027,  0.0110, -0.2560, -0.3005, -0.1067],
#           [ 0.2773,  0.2219,  0.0554, -0.0651, -0.0885],
#           [ 0.1367, -0.1514, -0.3074, -0.1992,  0.2225]]],
#
#
#         [[[ 0.0220, -0.1393,  0.2391,  0.0354, -0.1309],
#           [ 0.1662,  0.2442, -0.0303,  0.1536, -0.1857],
#           [-0.0571,  0.1664, -0.1277, -0.0071, -0.3380],
#           [ 0.1753,  0.1025, -0.1652,  0.1522, -0.0153],
#           [-0.2676,  0.0350,  0.0850, -0.0108,  0.2412]]],
#
#
#         [[[-0.0936, -0.0724, -0.1145,  0.1809,  0.1123],
#           [ 0.0697,  0.2309,  0.0336,  0.2533,  0.1725],
#           [ 0.0659,  0.2416,  0.0571,  0.1563,  0.0774],
#           [-0.1848, -0.1439, -0.1821, -0.0702, -0.1202],
#           [ 0.1542,  0.0665,  0.0406, -0.1901, -0.3174]]],
#
#
#         [[[ 0.0837,  0.0153,  0.2334, -0.0559, -0.3326],
#           [-0.1655, -0.0735,  0.3182,  0.1149, -0.2299],
#           [-0.1970, -0.0713,  0.3137, -0.0336,  0.0705],
#           [-0.2605,  0.1102,  0.0249,  0.0049, -0.0116],
#           [ 0.0366, -0.1495,  0.1592, -0.0636,  0.1053]]],
#
#
#         [[[-0.1465, -0.0688, -0.1923,  0.0018,  0.2641],
#           [-0.1228, -0.1574, -0.3342, -0.2719,  0.0285],
#           [ 0.3145,  0.1077, -0.1280, -0.3167,  0.0511],
#           [ 0.2035,  0.0950,  0.2908, -0.1905, -0.0051],
#           [ 0.0710,  0.0933,  0.1470,  0.1892, -0.1844]]]], device='cuda:0')
# tensor([ 0.0676,  0.1510, -0.0481,  0.0978, -0.1315, -0.0666,  0.1526,  0.1776,
#         -0.2446,  0.2205], device='cuda:0')
